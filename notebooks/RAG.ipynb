# %%
import chromadb

# %%
from sentence_transformers import SentenceTransformer
client = chromadb.PersistentClient(
    path="../vector_db"
)
collection = client.get_collection(
    name="notes"
)

# %%
model = SentenceTransformer(
    "sentence-transformers/all-MiniLM-L6-v2"
)
query = input("Ask a question: ")
query_embedding = model.encode(query)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
query_embedding = model.encode(query)

results = collection.query(
    query_embeddings=[query_embedding.tolist()],
    n_results=5
)

retrieved_chunks = results["documents"][0]

context = "\n\n".join(retrieved_chunks)

prompt = f"""
Context:

{context}

Question:

{query}

Answer:
"""

# %%
from dotenv import load_dotenv
import google.generativeai as genai
import os

load_dotenv()
genai.configure(
    api_key=os.getenv("GOOGLE_API_KEY")
)
model = genai.GenerativeModel(
    "gemini-2.5-flash"
)

# %%
response = model.generate_content(prompt)
print(response.text)
# Out:
# Deep learning is a computer software that mimics the network of neurons in a brain. It is a subset of machine learning that makes use of deep neural networks.
#
# These deep learning algorithms are constructed with many connected layers: an Input Layer, an Output Layer, and multiple Hidden Layers in between. The term "deep" indicates that the network joins neurons in more than two layers.
#
# Deep learning uses these neural networks to analyze complex data and make decisions based on what it learns, often by example, to closely replicate human processes. It provides solutions for real-world problems in areas like computer vision, speech recognition, and natural language processing.
